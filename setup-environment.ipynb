# %%
import time
begin = time.time()

# %%
# %%bash
# set -e
# python3.6 -m virtualenv coffea-jerc
# source coffea-jerc/bin/activate
# pip install -r requirements.txt
# ipython kernel install --user --name=coffea-jerc
# Out:
# Using base prefix '/usr'
# New python executable in /home/cms.mmorris/coffeajerc/CoffeaJERC/coffea-jerc/bin/python3.6
# Also creating executable in /home/cms.mmorris/coffeajerc/CoffeaJERC/coffea-jerc/bin/python
# Installing setuptools, pip, wheel...
# done.
# Collecting aiohttp==3.7.4
#   Downloading aiohttp-3.7.4-cp36-cp36m-manylinux2014_x86_64.whl (1.3 MB)
# Collecting anyio==3.1.0
#   Downloading anyio-3.1.0-py3-none-any.whl (74 kB)
# Collecting argon2-cffi==20.1.0
#   Downloading argon2_cffi-20.1.0-cp35-abi3-manylinux1_x86_64.whl (97 kB)
# Collecting async-generator==1.10
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting async-timeout==3.0.1
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Collecting attrs==21.2.0
#   Downloading attrs-21.2.0-py2.py3-none-any.whl (53 kB)
# Collecting awkward==1.3.0
#   Downloading awkward-1.3.0-cp36-cp36m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (8.1 MB)
# Collecting awkward0==0.15.5
#   Downloading awkward0-0.15.5-py3-none-any.whl (87 kB)
# Collecting Babel==2.9.1
#   Downloading Babel-2.9.1-py2.py3-none-any.whl (8.8 MB)
# Collecting backcall==0.2.0
#   Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting backports.functools-lru-cache==1.6.4
#   Downloading backports.functools_lru_cache-1.6.4-py2.py3-none-any.whl (5.9 kB)
# Collecting beautifulsoup4==4.9.3
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
# Collecting bleach==3.3.0
#   Downloading bleach-3.3.0-py2.py3-none-any.whl (283 kB)
# Collecting blosc==1.10.2
#   Downloading blosc-1.10.2.tar.gz (858 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting bokeh==2.2.3
#   Downloading bokeh-2.2.3.tar.gz (8.8 MB)
# Collecting boost-histogram==1.0.2
#   Downloading boost_histogram-1.0.2-cp36-cp36m-manylinux1_x86_64.whl (1.9 MB)
# Collecting brotlipy==0.7.0
#   Downloading brotlipy-0.7.0-cp36-cp36m-manylinux1_x86_64.whl (920 kB)
# Collecting cachetools==4.2.2
#   Downloading cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting certifi==2021.5.30
#   Downloading certifi-2021.5.30-py2.py3-none-any.whl (145 kB)
# Collecting cffi==1.14.3
#   Downloading cffi-1.14.3-cp36-cp36m-manylinux1_x86_64.whl (400 kB)
# Collecting chardet==3.0.4
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting click==8.0.1
#   Downloading click-8.0.1-py3-none-any.whl (97 kB)
# Collecting cloudpickle==1.6.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting coffea==0.7.4
#   Downloading coffea-0.7.4-py2.py3-none-any.whl (165 kB)
# Collecting conda
#   Downloading conda-4.3.16.tar.gz (299 kB)
# Collecting conda-build
#   Downloading conda_build-2.1.5-py3-none-any.whl (235 kB)
# Collecting cryptography==3.2.1
#   Downloading cryptography-3.2.1-cp35-abi3-manylinux2010_x86_64.whl (2.6 MB)
# Collecting cycler==0.10.0
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting cytoolz==0.11.0
#   Downloading cytoolz-0.11.0.tar.gz (477 kB)
# Collecting decorator==5.0.9
#   Downloading decorator-5.0.9-py3-none-any.whl (8.9 kB)
# Collecting defusedxml==0.7.1
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting entrypoints==0.3
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting filelock==3.0.12
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Collecting fsspec==2021.5.0
#   Downloading fsspec-2021.5.0-py3-none-any.whl (111 kB)
# Collecting future==0.18.2
#   Downloading future-0.18.2.tar.gz (829 kB)
# Collecting glob2==0.7
#   Downloading glob2-0.7.tar.gz (10 kB)
# Collecting HeapDict==1.0.1
#   Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Collecting hist==2.3.0
#   Downloading hist-2.3.0-py3-none-any.whl (30 kB)
# Collecting histoprint==2.1.0
#   Downloading histoprint-2.1.0-py3-none-any.whl (15 kB)
# Collecting idna==2.10
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting importlib-metadata==4.5.0
#   Downloading importlib_metadata-4.5.0-py3-none-any.whl (17 kB)
# Collecting jedi==0.18.0
#   Downloading jedi-0.18.0-py2.py3-none-any.whl (1.4 MB)
# Collecting Jinja2==3.0.1
#   Downloading Jinja2-3.0.1-py3-none-any.whl (133 kB)
# Collecting joblib==1.0.1
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
# Collecting json5==0.9.5
#   Downloading json5-0.9.5-py2.py3-none-any.whl (17 kB)
# Collecting jsonschema==3.2.0
#   Downloading jsonschema-3.2.0-py2.py3-none-any.whl (56 kB)
# Collecting kiwisolver==1.3.1
#   Downloading kiwisolver-1.3.1-cp36-cp36m-manylinux1_x86_64.whl (1.1 MB)
# Collecting libarchive-c==3.1
#   Downloading libarchive_c-3.1-py2.py3-none-any.whl (12 kB)
# Collecting llvmlite==0.36.0
#   Downloading llvmlite-0.36.0-cp36-cp36m-manylinux2010_x86_64.whl (25.3 MB)
# Collecting locket==0.2.0
#   Downloading locket-0.2.0.tar.gz (3.5 kB)
# Collecting lz4==3.1.3
#   Downloading lz4-3.1.3-cp36-cp36m-manylinux2010_x86_64.whl (1.8 MB)
# Collecting MarkupSafe==2.0.1
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux2010_x86_64.whl (30 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.3.4-cp36-cp36m-manylinux1_x86_64.whl (11.5 MB)
# Collecting matplotlib-inline==0.1.2
#   Downloading matplotlib_inline-0.1.2-py3-none-any.whl (8.2 kB)
# Collecting mistune==0.8.4
#   Downloading mistune-0.8.4-py2.py3-none-any.whl (16 kB)
# Collecting mplhep
#   Downloading mplhep-0.2.18-py3-none-any.whl (5.4 MB)
# Collecting msgpack==1.0.2
#   Downloading msgpack-1.0.2-cp36-cp36m-manylinux1_x86_64.whl (272 kB)
# Collecting multidict==5.1.0
#   Downloading multidict-5.1.0-cp36-cp36m-manylinux2014_x86_64.whl (141 kB)
# Collecting nest-asyncio==1.5.1
#   Downloading nest_asyncio-1.5.1-py3-none-any.whl (5.0 kB)
# Collecting numba==0.53.1
#   Downloading numba-0.53.1-cp36-cp36m-manylinux2014_x86_64.whl (3.4 MB)
# Collecting numpy
#   Downloading numpy-1.19.5-cp36-cp36m-manylinux2010_x86_64.whl (14.8 MB)
# Collecting olefile==0.46
#   Downloading olefile-0.46.zip (112 kB)
# Collecting packaging==20.9
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
# Collecting pandas
#   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting pandocfilters
#   Downloading pandocfilters-1.4.3.tar.gz (16 kB)
# Collecting parso==0.8.2
#   Downloading parso-0.8.2-py2.py3-none-any.whl (94 kB)
# Collecting partd==1.2.0
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Collecting pexpect==4.8.0
#   Downloading pexpect-4.8.0-py2.py3-none-any.whl (59 kB)
# Collecting pickleshare==0.7.5
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting Pillow==8.2.0
#   Downloading Pillow-8.2.0-cp36-cp36m-manylinux1_x86_64.whl (3.0 MB)
# Collecting pkginfo==1.7.0
#   Downloading pkginfo-1.7.0-py2.py3-none-any.whl (25 kB)
# Collecting prometheus-client==0.11.0
#   Downloading prometheus_client-0.11.0-py2.py3-none-any.whl (56 kB)
# Collecting prompt-toolkit==3.0.18
#   Downloading prompt_toolkit-3.0.18-py3-none-any.whl (367 kB)
# Collecting psutil==5.8.0
#   Downloading psutil-5.8.0-cp36-cp36m-manylinux2010_x86_64.whl (291 kB)
# Collecting ptyprocess==0.7.0
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting pyarrow==4.0.1
#   Downloading pyarrow-4.0.1-cp36-cp36m-manylinux2014_x86_64.whl (21.9 MB)
# Collecting pycosat==0.6.3
#   Downloading pycosat-0.6.3.zip (66 kB)
# Collecting pycparser==2.20
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting Pygments==2.9.0
#   Downloading Pygments-2.9.0-py3-none-any.whl (1.0 MB)
# Collecting pyOpenSSL==19.1.0
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting pyrsistent==0.17.3
#   Downloading pyrsistent-0.17.3.tar.gz (106 kB)
# Collecting PySocks==1.7.1
#   Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting pytz==2021.1
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting PyYAML==5.4.1
#   Downloading PyYAML-5.4.1-cp36-cp36m-manylinux1_x86_64.whl (640 kB)
# Collecting pyzmq==22.1.0
#   Downloading pyzmq-22.1.0-cp36-cp36m-manylinux1_x86_64.whl (1.1 MB)
# Collecting requests==2.24.0
#   Downloading requests-2.24.0-py2.py3-none-any.whl (61 kB)
# Collecting ruamel-yaml==0.15.87
#   Downloading ruamel.yaml-0.15.87-cp36-cp36m-manylinux1_x86_64.whl (664 kB)
# Collecting scikit-learn==0.24.2
#   Downloading scikit_learn-0.24.2-cp36-cp36m-manylinux2010_x86_64.whl (22.2 MB)
# Collecting scipy==1.5.3
#   Downloading scipy-1.5.3-cp36-cp36m-manylinux1_x86_64.whl (25.9 MB)
# Collecting Send2Trash==1.5.0
#   Downloading Send2Trash-1.5.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: setuptools in ./coffea-jerc/lib/python3.6/site-packages (from -r requirements.txt (line 92)) (57.0.0)
# Collecting simpervisor==0.4
#   Downloading simpervisor-0.4-py3-none-any.whl (5.7 kB)
# Collecting six==1.15.0
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting sklearn==0.0
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting sniffio==1.2.0
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting sortedcontainers==2.4.0
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting soupsieve==2.0.1
#   Downloading soupsieve-2.0.1-py3-none-any.whl (32 kB)
# Collecting style==1.1.0
#   Downloading style-1.1.0-py2.py3-none-any.whl (6.4 kB)
# Collecting tblib==1.7.0
#   Downloading tblib-1.7.0-py2.py3-none-any.whl (12 kB)
# Collecting terminado==0.10.0
#   Downloading terminado-0.10.0-py3-none-any.whl (14 kB)
# Collecting testpath==0.5.0
#   Downloading testpath-0.5.0-py3-none-any.whl (84 kB)
# Collecting threadpoolctl==2.1.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Collecting toolz==0.11.1
#   Downloading toolz-0.11.1-py3-none-any.whl (55 kB)
# Collecting tornado==6.1
#   Downloading tornado-6.1-cp36-cp36m-manylinux2010_x86_64.whl (427 kB)
# Collecting tqdm==4.51.0
#   Downloading tqdm-4.51.0-py2.py3-none-any.whl (70 kB)
# Collecting traitlets
#   Downloading traitlets-4.3.3-py2.py3-none-any.whl (75 kB)
# Collecting typing-extensions==3.10.0.0
#   Downloading typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Collecting uhi==0.2.1
#   Downloading uhi-0.2.1-py3-none-any.whl (8.6 kB)
# Collecting uncertainties==3.1.5
#   Downloading uncertainties-3.1.5-py2.py3-none-any.whl (246 kB)
# Collecting update==0.0.1
#   Downloading update-0.0.1-py2.py3-none-any.whl (2.9 kB)
# Collecting uproot==4.0.8
#   Downloading uproot-4.0.8-py2.py3-none-any.whl (241 kB)
# Collecting uproot3==3.14.4
#   Downloading uproot3-3.14.4-py3-none-any.whl (117 kB)
# Collecting uproot3-methods==0.10.1
#   Downloading uproot3_methods-0.10.1-py3-none-any.whl (32 kB)
# Collecting urllib3==1.25.11
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
# Collecting wcwidth==0.2.5
#   Downloading wcwidth-0.2.5-py2.py3-none-any.whl (30 kB)
# Collecting webencodings==0.5.1
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting websocket-client==0.57.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting wheel==0.35.1
#   Downloading wheel-0.35.1-py2.py3-none-any.whl (33 kB)
# Collecting widgetsnbextension==3.5.1
#   Downloading widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
# Collecting xxhash==2.0.2
#   Downloading xxhash-2.0.2-cp36-cp36m-manylinux2010_x86_64.whl (243 kB)
# Collecting yarl==1.6.3
#   Downloading yarl-1.6.3-cp36-cp36m-manylinux2014_x86_64.whl (293 kB)
# Collecting zict==2.0.0
#   Downloading zict-2.0.0-py3-none-any.whl (10 kB)
# Collecting zipp==3.4.1
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Collecting zstandard==0.15.2
#   Downloading zstandard-0.15.2-cp36-cp36m-manylinux2014_x86_64.whl (2.2 MB)
# Collecting idna-ssl>=1.0
#   Downloading idna-ssl-1.1.0.tar.gz (3.4 kB)
# Collecting dataclasses
#   Downloading dataclasses-0.8-py3-none-any.whl (19 kB)
# Collecting python-dateutil>=2.1
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting ipywidgets
#   Downloading ipywidgets-7.6.3-py2.py3-none-any.whl (121 kB)
# Collecting contextvars>=2.1
#   Downloading contextvars-2.4.tar.gz (9.6 kB)
# Collecting notebook>=4.4.1
#   Downloading notebook-6.4.0-py3-none-any.whl (9.5 MB)
# Collecting immutables>=0.9
#   Downloading immutables-0.15-cp36-cp36m-manylinux1_x86_64.whl (100 kB)
# Collecting nbformat
#   Downloading nbformat-5.1.3-py3-none-any.whl (178 kB)
# Collecting jupyter-core>=4.6.1
#   Downloading jupyter_core-4.7.1-py3-none-any.whl (82 kB)
# Collecting ipykernel
#   Downloading ipykernel-5.5.5-py3-none-any.whl (120 kB)
# Collecting jupyter-client>=5.3.4
#   Downloading jupyter_client-6.1.12-py3-none-any.whl (112 kB)
# Collecting ipython-genutils
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting nbconvert
#   Downloading nbconvert-6.0.7-py3-none-any.whl (552 kB)
# Collecting ipython>=5.0.0
#   Downloading ipython-7.16.1-py3-none-any.whl (785 kB)
# Collecting jupyterlab-widgets>=1.0.0
#   Downloading jupyterlab_widgets-1.0.0-py3-none-any.whl (243 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.1.2-py2.py3-none-any.whl (4.6 kB)
# Collecting nbclient<0.6.0,>=0.5.0
#   Downloading nbclient-0.5.3-py3-none-any.whl (82 kB)
# Building wheels for collected packages: blosc, bokeh, cytoolz, future, glob2, locket, olefile, pycosat, pyrsistent, sklearn, contextvars, idna-ssl, conda, pandocfilters
#   Building wheel for blosc (PEP 517): started
#   Building wheel for blosc (PEP 517): finished with status 'done'
#   Created wheel for blosc: filename=blosc-1.10.2-cp36-cp36m-linux_x86_64.whl size=2160872 sha256=e60b37320ce3a452f9ab8598be5994005c4e36e319fe4a77987f5f38627ab642
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ooyzq1gk/wheels/25/ac/11/5268f9b74f868f4c55d3fa63e4e350543d93e4bd1035e66bfd
#   Building wheel for bokeh (setup.py): started
#   Building wheel for bokeh (setup.py): finished with status 'done'
#   Created wheel for bokeh: filename=bokeh-2.2.3-py3-none-any.whl size=9296319 sha256=38afb388588fce48d02a58fad001adabe991bf572c3f43c85fc05eb708355022
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ooyzq1gk/wheels/36/60/6b/2a439a4e4b2cb34846f97b81687bc8a6bb3a96c5574fb5dd6c
#   Building wheel for cytoolz (setup.py): started
#   Building wheel for cytoolz (setup.py): finished with status 'done'
#   Created wheel for cytoolz: filename=cytoolz-0.11.0-cp36-cp36m-linux_x86_64.whl size=1302119 sha256=37161d2195691be8a575899ad972adf599fc4b544df3e5755e6f588480e89421
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ooyzq1gk/wheels/71/ac/2e/3e6142aa6a43fe6e4ed7348f643349c8e3efe96ff8f7686901
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=59a0933a4aa93ba396dc928f906b53c307c086783ce0c28db92709fe20ba3be6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ooyzq1gk/wheels/6e/9c/ed/4499c9865ac1002697793e0ae05ba6be33553d098f3347fb94
#   Building wheel for glob2 (setup.py): started
#   Building wheel for glob2 (setup.py): finished with status 'done'
#   Created wheel for glob2: filename=glob2-0.7-py2.py3-none-any.whl size=9320 sha256=3b1e550d3c1264c2ee941963726d6db269c985d486dd10886d0d9bb806e5170e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ooyzq1gk/wheels/96/2f/ad/5bba2807c8e762a019e4abd6f70dafbab1889acda23192aeff
#   Building wheel for locket (setup.py): started
#   Building wheel for locket (setup.py): finished with status 'done'
#   Created wheel for locket: filename=locket-0.2.0-py3-none-any.whl size=4052 sha256=8b0b68ba2be5e950b96384780bf77eeb999f6ba15b667567ac410472c12ad4f9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ooyzq1gk/wheels/21/ca/95/1e41f9a9a7a06ba06874ad2bf0eac88e7ba02fe9a6ff26c77d
#   Building wheel for olefile (setup.py): started
#   Building wheel for olefile (setup.py): finished with status 'done'
#   Created wheel for olefile: filename=olefile-0.46-py2.py3-none-any.whl size=35431 sha256=3a8c5dbd6d5b18a066089d69a03fdd02ef74483e7644fe0dde0a0adcb826c138
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ooyzq1gk/wheels/bc/9d/f9/4f5e50f497a2ed398d9786244df90cee57583e92bff76bfc2b
#   Building wheel for pycosat (setup.py): started
#   Building wheel for pycosat (setup.py): finished with status 'done'
#   Created wheel for pycosat: filename=pycosat-0.6.3-cp36-cp36m-linux_x86_64.whl size=136403 sha256=8672395249a65d9dab60c21ea5bd2d1bc64abaf18972b2bd8956f7a5b51016ca
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ooyzq1gk/wheels/b1/af/79/39f8c1077c65f82a554730240cb461e4148155bc8435ae011a
#   Building wheel for pyrsistent (setup.py): started
#   Building wheel for pyrsistent (setup.py): finished with status 'done'
#   Created wheel for pyrsistent: filename=pyrsistent-0.17.3-cp36-cp36m-linux_x86_64.whl size=94659 sha256=5daa79240dbe1b4bad961d6a9b664a4338be8fb130499a2db396f01d69a843bb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ooyzq1gk/wheels/34/13/19/294da8e11bce7e563afee51251b9fa878185e14f4b5caf00cb
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1309 sha256=c7fc7087411af8495be3f098b0899eb9e35650088cd9d39a71e0295f5c7bdf63
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ooyzq1gk/wheels/23/9d/42/5ec745cbbb17517000a53cecc49d6a865450d1f5cb16dc8a9c
#   Building wheel for contextvars (setup.py): started
#   Building wheel for contextvars (setup.py): finished with status 'done'
#   Created wheel for contextvars: filename=contextvars-2.4-py3-none-any.whl size=7680 sha256=3f4d8fe42fb061e5073892311f52bf8af5cc59c5ce34549fa349d449dbf83c86
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ooyzq1gk/wheels/41/11/53/911724983aa48deb94792432e14e518447212dd6c5477d49d3
#   Building wheel for idna-ssl (setup.py): started
#   Building wheel for idna-ssl (setup.py): finished with status 'done'
#   Created wheel for idna-ssl: filename=idna_ssl-1.1.0-py3-none-any.whl size=3178 sha256=caa735489201a9085fc12de0b5713eb85aa3d553524843581fbdb697649afdb5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ooyzq1gk/wheels/6a/f5/9c/f8331a854f7a8739cf0e74c13854e4dd7b1af11b04fe1dde13
#   Building wheel for conda (setup.py): started
#   Building wheel for conda (setup.py): finished with status 'done'
#   Created wheel for conda: filename=conda-4.3.16-py3-none-any.whl size=336960 sha256=44209bad6250c991be4977d8b2042f8d28728e35ac759531afe8ef70a2771b19
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ooyzq1gk/wheels/43/c8/c2/9a6bf4f590a78be935114d85d9a3eef6524f21287570fc2f97
#   Building wheel for pandocfilters (setup.py): started
#   Building wheel for pandocfilters (setup.py): finished with status 'done'
#   Created wheel for pandocfilters: filename=pandocfilters-1.4.3-py3-none-any.whl size=8006 sha256=93d27fa7ca5f56dadf823ff4767c66301381412c6521272b4c92438baa69c9ce
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ooyzq1gk/wheels/12/12/89/fe63ac4d6ee6440daab4db77b78c63f7f192b700f844b6639f
# Successfully built blosc bokeh cytoolz future glob2 locket olefile pycosat pyrsistent sklearn contextvars idna-ssl conda pandocfilters
# Installing collected packages: zipp, typing-extensions, six, ipython-genutils, decorator, traitlets, pyrsistent, importlib-metadata, attrs, wcwidth, tornado, pyzmq, python-dateutil, pyparsing, ptyprocess, parso, jupyter-core, jsonschema, webencodings, Pygments, pycparser, prompt-toolkit, pickleshare, pexpect, packaging, nest-asyncio, nbformat, MarkupSafe, jupyter-client, jedi, backcall, async-generator, testpath, pandocfilters, nbclient, mistune, jupyterlab-pygments, Jinja2, ipython, entrypoints, defusedxml, cffi, bleach, terminado, Send2Trash, prometheus-client, numpy, nbconvert, ipykernel, argon2-cffi, urllib3, Pillow, notebook, kiwisolver, immutables, idna, dataclasses, cycler, click, chardet, certifi, awkward0, widgetsnbextension, uproot3-methods, threadpoolctl, scipy, ruamel-yaml, requests, pytz, pycosat, multidict, matplotlib, llvmlite, jupyterlab-widgets, joblib, histoprint, contextvars, cachetools, boost-histogram, yarl, uproot3, uproot, tqdm, toolz, style, soupsieve, sniffio, scikit-learn, PyYAML, pyarrow, pandas, numba, mplhep, lz4, locket, ipywidgets, idna-ssl, hist, HeapDict, future, filelock, cryptography, conda, cloudpickle, awkward, async-timeout, zstandard, zict, xxhash, wheel, websocket-client, update, uncertainties, uhi, tblib, sortedcontainers, sklearn, simpervisor, PySocks, pyOpenSSL, psutil, pkginfo, partd, olefile, msgpack, matplotlib-inline, libarchive-c, json5, glob2, fsspec, cytoolz, conda-build, coffea, brotlipy, bokeh, blosc, beautifulsoup4, backports.functools-lru-cache, Babel, anyio, aiohttp
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.36.2
#     Uninstalling wheel-0.36.2:
#       Successfully uninstalled wheel-0.36.2
# Successfully installed Babel-2.9.1 HeapDict-1.0.1 Jinja2-3.0.1 MarkupSafe-2.0.1 Pillow-8.2.0 PySocks-1.7.1 PyYAML-5.4.1 Pygments-2.9.0 Send2Trash-1.5.0 aiohttp-3.7.4 anyio-3.1.0 argon2-cffi-20.1.0 async-generator-1.10 async-timeout-3.0.1 attrs-21.2.0 awkward-1.3.0 awkward0-0.15.5 backcall-0.2.0 backports.functools-lru-cache-1.6.4 beautifulsoup4-4.9.3 bleach-3.3.0 blosc-1.10.2 bokeh-2.2.3 boost-histogram-1.0.2 brotlipy-0.7.0 cachetools-4.2.2 certifi-2021.5.30 cffi-1.14.3 chardet-3.0.4 click-8.0.1 cloudpickle-1.6.0 coffea-0.7.4 conda-4.3.16 conda-build-2.1.5 contextvars-2.4 cryptography-3.2.1 cycler-0.10.0 cytoolz-0.11.0 dataclasses-0.8 decorator-5.0.9 defusedxml-0.7.1 entrypoints-0.3 filelock-3.0.12 fsspec-2021.5.0 future-0.18.2 glob2-0.7 hist-2.3.0 histoprint-2.1.0 idna-2.10 idna-ssl-1.1.0 immutables-0.15 importlib-metadata-4.5.0 ipykernel-5.5.5 ipython-7.16.1 ipython-genutils-0.2.0 ipywidgets-7.6.3 jedi-0.18.0 joblib-1.0.1 json5-0.9.5 jsonschema-3.2.0 jupyter-client-6.1.12 jupyter-core-4.7.1 jupyterlab-pygments-0.1.2 jupyterlab-widgets-1.0.0 kiwisolver-1.3.1 libarchive-c-3.1 llvmlite-0.36.0 locket-0.2.0 lz4-3.1.3 matplotlib-3.3.4 matplotlib-inline-0.1.2 mistune-0.8.4 mplhep-0.2.18 msgpack-1.0.2 multidict-5.1.0 nbclient-0.5.3 nbconvert-6.0.7 nbformat-5.1.3 nest-asyncio-1.5.1 notebook-6.4.0 numba-0.53.1 numpy-1.19.5 olefile-0.46 packaging-20.9 pandas-1.1.5 pandocfilters-1.4.3 parso-0.8.2 partd-1.2.0 pexpect-4.8.0 pickleshare-0.7.5 pkginfo-1.7.0 prometheus-client-0.11.0 prompt-toolkit-3.0.18 psutil-5.8.0 ptyprocess-0.7.0 pyOpenSSL-19.1.0 pyarrow-4.0.1 pycosat-0.6.3 pycparser-2.20 pyparsing-2.4.7 pyrsistent-0.17.3 python-dateutil-2.8.1 pytz-2021.1 pyzmq-22.1.0 requests-2.24.0 ruamel-yaml-0.15.87 scikit-learn-0.24.2 scipy-1.5.3 simpervisor-0.4 six-1.15.0 sklearn-0.0 sniffio-1.2.0 sortedcontainers-2.4.0 soupsieve-2.0.1 style-1.1.0 tblib-1.7.0 terminado-0.10.0 testpath-0.5.0 threadpoolctl-2.1.0 toolz-0.11.1 tornado-6.1 tqdm-4.51.0 traitlets-4.3.3 typing-extensions-3.10.0.0 uhi-0.2.1 uncertainties-3.1.5 update-0.0.1 uproot-4.0.8 uproot3-3.14.4 uproot3-methods-0.10.1 urllib3-1.25.11 wcwidth-0.2.5 webencodings-0.5.1 websocket-client-0.57.0 wheel-0.35.1 widgetsnbextension-3.5.1 xxhash-2.0.2 yarl-1.6.3 zict-2.0.0 zipp-3.4.1 zstandard-0.15.2
# Installed kernelspec coffea-jerc in /home/cms.mmorris/.local/share/jupyter/kernels/coffea-jerc

# %%
time.time()-begin
# Out:
# 211.5013279914856
